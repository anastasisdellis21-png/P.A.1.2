# %%
my_list=[5,10,4,4,6]
new_list=[x/3 for x in my_list]
formatted_list = [f"{x:.2f}" for x in new_list]
print(f"the new_list is equal to {formatted_list}")
# Out:
# the new_list is equal to ['1.67', '3.33', '1.33', '1.33', '2.00']
